# %%
# !pip install bertopic[visualization] --quiet
# Out:
# WARNING: bertopic 0.16.4 does not provide the extra 'visualization'
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 18.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.8/88.8 kB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 2.0 MB/s eta 0:00:00

# %%
import numpy as np
import pandas as pd
from copy import deepcopy
from bertopic import BERTopic

# %%
df = pd.read_csv("amazon_alexa.tsv", sep='\t') # Specify the delimiter as '\t' for tab-separated values


df.head(3)
# Out:
#    rating       date         variation  \
# 0       5  31-Jul-18  Charcoal Fabric
# 1       5  31-Jul-18  Charcoal Fabric
# 2       4  31-Jul-18    Walnut Finish
#
#                                     verified_reviews  feedback
# 0                                      Love my Echo!         1
# 1                                          Loved it!         1
# 2  Sometimes while playing a game, you can answer...         1

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Download the missing 'punkt_tab' data
nltk.download('punkt_tab') # This line is added to download the necessary data
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import re

stop_words = set(stopwords.words('english'))
stop_words.update(['.', ',', '"', "'", '?', '!', ':', ';', '(', ')', '[', ']', '{', '}']) # Add more stopwords as needed

def preprocess_text(text):
    # Check if text is a string before applying lower()
    if isinstance(text, str):
        # Lowercase the text
        text = text.lower()
        # Remove special characters and numbers
        text = re.sub(r'[^a-zA-Z\s]', '', text)
        # Tokenize the text
        words = word_tokenize(text)
        # Remove stop words
        words = [w for w in words if not w in stop_words]
        # Join the words back into a string
        text = ' '.join(words)
        return text
    else:
        # Handle non-string values (e.g., return empty string or NaN)
        return '' # Or return np.nan if you prefer to keep track of missing values

df['processed_text'] = df['verified_reviews'].apply(lambda x: preprocess_text(x))

docs = df['processed_text'].to_list()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
docs[:5]
# Out:
# ['love echo',
#  'loved',
#  'sometimes playing game answer question correctly alexa says got wrong answers like able turn lights away home',
#  'lot fun thing yr old learns dinosaurs control lights play games like categories nice sound playing music well',
#  'music']

# %%
model = BERTopic(language="english")


topics, probs = model.fit_transform(docs)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
model.get_topic_freq()
# Out:
#     Topic  Count
# 2      -1    840
# 4       0    147
# 15      1    108
# 74      2    105
# 1       3     96
# ..    ...    ...
# 57     73     12
# 14     74     11
# 78     75     11
# 26     76     10
# 13     77     10
#
# [79 rows x 2 columns]

# %%
model.get_topic(0)
# Out:
# [('stick', 0.06605514790452921),
#  ('fire', 0.060905075779274905),
#  ('cable', 0.039290365375545686),
#  ('firestick', 0.03774174605119782),
#  ('tv', 0.0371085057709447),
#  ('watch', 0.027929614150062686),
#  ('shows', 0.023924004972284987),
#  ('streaming', 0.02129819687505723),
#  ('apps', 0.020886370189860354),
#  ('hulu', 0.020249148510847328)]

# %%
model.get_topic(2)
# Out:
# [('stick', 0.06605514790452921),
#  ('fire', 0.060905075779274905),
#  ('cable', 0.039290365375545686),
#  ('firestick', 0.03774174605119782),
#  ('tv', 0.0371085057709447),
#  ('watch', 0.027929614150062686),
#  ('shows', 0.023924004972284987),
#  ('streaming', 0.02129819687505723),
#  ('apps', 0.020886370189860354),
#  ('hulu', 0.020249148510847328)]

# %%
model.get_topic(14)
# Out:
# [('loves', 0.14673871427454024),
#  ('daughter', 0.08959119547181135),
#  ('mother', 0.0731538596369911),
#  ('bought', 0.07234249058361943),
#  ('son', 0.058495859698114896),
#  ('wife', 0.0538045052179273),
#  ('knee', 0.04394709735728997),
#  ('dancing', 0.04394709735728997),
#  ('exho', 0.04394709735728997),
#  ('granddaughter', 0.04394709735728997)]

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
